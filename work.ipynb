# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
import ast
import json

# %%
geo_info = pd.read_csv('geo_info.csv', delimiter = ';')
referer_vectors = pd.read_csv('referer_vectors.csv', delimiter = ';')
test_users = pd.read_csv('test_users.csv', delimiter = ';')
test = pd.read_csv('test.csv', delimiter = ';')
train = pd.read_csv('train (1).csv', delimiter = ';')
train_labels = pd.read_csv('train_labels.csv', delimiter = ';')

# %%
train.head()
# Out:
#    request_ts                           user_id                   referer  \
# 0  1701011363  fb858e8e0a2bec074450eaf94b627fd3          https://9b48ee5/
# 1  1700986581  46a5f128fd569c764a92c2eaa788095e          https://9b48ee5/
# 2  1701011071  5a74e9ac53ffb21a20cce117c0ad77ba  https://9634fd0/1409e548
# 3  1700992803  af735816ca19115431ae3d89518c8c91          https://9b48ee5/
# 4  1701021666  364f0ae0a3f29a685c4fb5bae6033b9a          https://9b48ee5/
#
#    geo_id                                         user_agent
# 0    4799  {'browser': 'Chrome Mobile', 'browser_version'...
# 1    8257  {'browser': 'Chrome Mobile', 'browser_version'...
# 2    3150  {'browser': 'Yandex Browser', 'browser_version...
# 3    2740  {'browser': 'Chrome Mobile', 'browser_version'...
# 4    4863  {'browser': 'Yandex Browser', 'browser_version...

# %%
train.isnull().sum()
# Out:
# request_ts    0
# user_id       0
# referer       0
# geo_id        0
# user_agent    1
# dtype: int64

# %%
#Удалим пропущенные строки, так как они влияют на обучение модели

# %%
train = train.dropna(subset = ['user_agent'])

# %%
train['user_agent'].nunique()
# Out:
# 8432

# %%
#Преобразуем колонку user_agent

# %%
train['user_agent'] = train['user_agent'].apply(ast.literal_eval)
df_exp = pd.json_normalize(train['user_agent'])
train = pd.concat([train, df_exp], axis = 1).drop(columns = ['user_agent'], axis = 1)

# %%
train.head()
# Out:
#      request_ts                           user_id                   referer  \
# 0  1.701011e+09  fb858e8e0a2bec074450eaf94b627fd3          https://9b48ee5/
# 1  1.700987e+09  46a5f128fd569c764a92c2eaa788095e          https://9b48ee5/
# 2  1.701011e+09  5a74e9ac53ffb21a20cce117c0ad77ba  https://9634fd0/1409e548
# 3  1.700993e+09  af735816ca19115431ae3d89518c8c91          https://9b48ee5/
# 4  1.701022e+09  364f0ae0a3f29a685c4fb5bae6033b9a          https://9b48ee5/
#
#    geo_id         browser browser_version       os os_version
# 0  4799.0   Chrome Mobile         119.0.0  Android         10
# 1  8257.0   Chrome Mobile         111.0.0  Android         10
# 2  3150.0  Yandex Browser         20.12.5  Android         11
# 3  2740.0   Chrome Mobile         119.0.0  Android         10
# 4  4863.0  Yandex Browser         18.11.1  Android      4.4.4

# %%
train['request_ts'].nunique()
# Out:
# 85501

# %%
#Удалим колонку request_ts из за большого количества различных данных

# %%
train = train.drop(['request_ts'], axis = 1)

# %%
train.head()
# Out:
#                             user_id                   referer  geo_id  \
# 0  fb858e8e0a2bec074450eaf94b627fd3          https://9b48ee5/  4799.0
# 1  46a5f128fd569c764a92c2eaa788095e          https://9b48ee5/  8257.0
# 2  5a74e9ac53ffb21a20cce117c0ad77ba  https://9634fd0/1409e548  3150.0
# 3  af735816ca19115431ae3d89518c8c91          https://9b48ee5/  2740.0
# 4  364f0ae0a3f29a685c4fb5bae6033b9a          https://9b48ee5/  4863.0
#
#           browser browser_version       os os_version
# 0   Chrome Mobile         119.0.0  Android         10
# 1   Chrome Mobile         111.0.0  Android         10
# 2  Yandex Browser         20.12.5  Android         11
# 3   Chrome Mobile         119.0.0  Android         10
# 4  Yandex Browser         18.11.1  Android      4.4.4

# %%
train.isnull().sum()
# Out:
# user_id            1
# referer            1
# geo_id             1
# browser            1
# browser_version    1
# os                 1
# os_version         1
# dtype: int64

# %%
#Удалим пропущенные значения

# %%
train = train.dropna(subset = ['user_id', 'referer', 'geo_id', 'os'])

# %%
train.isnull().sum()
# Out:
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# dtype: int64

# %%
#Повторим все то же самое для test df

# %%
test.isnull().sum()
# Out:
# request_ts    0
# user_id       0
# referer       0
# geo_id        0
# user_agent    0
# dtype: int64

# %%
test['user_agent'] = test['user_agent'].apply(ast.literal_eval)
df_exp_test = pd.json_normalize(test['user_agent'])
test = pd.concat([test, df_exp_test], axis = 1).drop(columns = ['user_agent'], axis = 1)

# %%
test.head()
# Out:
#    request_ts                           user_id                   referer  \
# 0  1700993094  c2802dadd33d8ae09bb366bdd41212ea          https://9b48ee5/
# 1  1701005579  e5b1988db74527ec092f28b0bbfdaac9          https://9b48ee5/
# 2  1700969752  6ef1eedbdb72554e53e69782066065c5  https://72879b4/12411b9e
# 3  1700991608  7e057293ecae62985a327b7af51858ea          https://9b48ee5/
# 4  1701019815  a27bd7ce8828497823fa8d5d05e7bbf7          https://9b48ee5/
#
#    geo_id        browser browser_version       os os_version
# 0    8816  Chrome Mobile       96.0.4664  Android         12
# 1    3663         Chrome      116.0.5845  Android         10
# 2    2336         Chrome         114.0.0  Android         10
# 3    9652  Chrome Mobile       91.0.4472  Android         11
# 4    3871  Chrome Mobile         119.0.0  Android         10

# %%
test.isnull().sum()
# Out:
# request_ts         0
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# dtype: int64

# %%
print('region_id', geo_info['region_id'].nunique())
print('country_id', geo_info['country_id'].nunique())
print('timezone_id', geo_info['timezone_id'].nunique())
print('geo_id', geo_info['geo_id'].nunique())
# Out:
# region_id 277
# country_id 203
# timezone_id 314
# geo_id 5533

# %%
geo_info.isnull().sum()
# Out:
# geo_id            0
# country_id        0
# region_id      1707
# timezone_id       0
# dtype: int64

# %%
geo_info['region_id'] = geo_info['region_id'].fillna('Unknown')

# %%
train_with_geo = pd.merge(train, geo_info, on = 'geo_id', how = 'inner')
train_with_geo.isnull().sum()
# Out:
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# country_id         0
# region_id          0
# timezone_id        0
# dtype: int64

# %%
test_with_geo = pd.merge(test, geo_info, on = 'geo_id', how = 'inner')
test_with_geo.isnull().sum()
# Out:
# request_ts         0
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# country_id         0
# region_id          0
# timezone_id        0
# dtype: int64

# %%
train_with_geo.head()
# Out:
#                             user_id                   referer  geo_id  \
# 0  fb858e8e0a2bec074450eaf94b627fd3          https://9b48ee5/  4799.0
# 1  46a5f128fd569c764a92c2eaa788095e          https://9b48ee5/  8257.0
# 2  5a74e9ac53ffb21a20cce117c0ad77ba  https://9634fd0/1409e548  3150.0
# 3  af735816ca19115431ae3d89518c8c91          https://9b48ee5/  2740.0
# 4  364f0ae0a3f29a685c4fb5bae6033b9a          https://9b48ee5/  4863.0
#
#           browser browser_version       os os_version country_id region_id  \
# 0   Chrome Mobile         119.0.0  Android         10     c31b4e    470e75
# 1   Chrome Mobile         111.0.0  Android         10     c31b4e    44520b
# 2  Yandex Browser         20.12.5  Android         11     c31b4e    616bb9
# 3   Chrome Mobile         119.0.0  Android         10     c31b4e    3c9dca
# 4  Yandex Browser         18.11.1  Android      4.4.4     c31b4e    776e76
#
#   timezone_id
# 0      f6155e
# 1      e56e80
# 2      af47f1
# 3      e56e80
# 4     10b7947

# %%
train_geo_labels = pd.merge(train_with_geo, train_labels, on = 'user_id', how = 'inner')

# %%
train_geo_labels.isnull().sum()
# Out:
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# country_id         0
# region_id          0
# timezone_id        0
# target             0
# dtype: int64

# %%
train_geo_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593442 entries, 0 to 593441
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          593442 non-null  object
#  1   referer          593442 non-null  object
#  2   geo_id           593442 non-null  float64
#  3   browser          593442 non-null  object
#  4   browser_version  593442 non-null  object
#  5   os               593442 non-null  object
#  6   os_version       593442 non-null  object
#  7   country_id       593442 non-null  object
#  8   region_id        593442 non-null  object
#  9   timezone_id      593442 non-null  object
#  10  target           593442 non-null  int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 49.8+ MB

# %%
referer_vectors.head()
# Out:
#    component0  component1  component2  component3  component4  component5  \
# 0       16708       -3741       11395       -1597       -3212        6269
# 1       11731        4045       22213       -1184       -8992        9381
# 2       10551        2947       12282        -470       16222        4472
# 3       12816       20498      -10110        7731        -569       12035
# 4        3710       11096       11333       14673        8030        1852
#
#    component6  component7  component8  component9                   referer
# 0        5610      -15351       13779       14102  https://a6899a4/15652e67
# 1       -3496       -3120        -899       16817          https://9b48ee5/
# 2       -3316        9606        4197       18948  https://7a4c700/161af7e3
# 3        3014        6398       11439        -271  https://9653126/159bc361
# 4       10554       11625        4306       13210  https://72879b4/125c29e6

# %%
referer_vectors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   component0  200000 non-null  int64
#  1   component1  200000 non-null  int64
#  2   component2  200000 non-null  int64
#  3   component3  200000 non-null  int64
#  4   component4  200000 non-null  int64
#  5   component5  200000 non-null  int64
#  6   component6  200000 non-null  int64
#  7   component7  200000 non-null  int64
#  8   component8  200000 non-null  int64
#  9   component9  200000 non-null  int64
#  10  referer     200000 non-null  object
# dtypes: int64(10), object(1)
# memory usage: 16.8+ MB

# %%
full_train = pd.merge(train_geo_labels, referer_vectors, on = 'referer', how = "inner")

# %%
full_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601289 entries, 0 to 601288
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          601289 non-null  object
#  1   referer          601289 non-null  object
#  2   geo_id           601289 non-null  float64
#  3   browser          601289 non-null  object
#  4   browser_version  601289 non-null  object
#  5   os               601289 non-null  object
#  6   os_version       601289 non-null  object
#  7   country_id       601289 non-null  object
#  8   region_id        601289 non-null  object
#  9   timezone_id      601289 non-null  object
#  10  target           601289 non-null  int64
#  11  component0       601289 non-null  int64
#  12  component1       601289 non-null  int64
#  13  component2       601289 non-null  int64
#  14  component3       601289 non-null  int64
#  15  component4       601289 non-null  int64
#  16  component5       601289 non-null  int64
#  17  component6       601289 non-null  int64
#  18  component7       601289 non-null  int64
#  19  component8       601289 non-null  int64
#  20  component9       601289 non-null  int64
# dtypes: float64(1), int64(11), object(9)
# memory usage: 96.3+ MB

# %%
full_train.isnull().sum()
# Out:
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# country_id         0
# region_id          0
# timezone_id        0
# target             0
# component0         0
# component1         0
# component2         0
# component3         0
# component4         0
# component5         0
# component6         0
# component7         0
# component8         0
# component9         0
# dtype: int64

# %%
full_train.head()
# Out:
#                             user_id                   referer  geo_id  \
# 0  fb858e8e0a2bec074450eaf94b627fd3          https://9b48ee5/  4799.0
# 1  46a5f128fd569c764a92c2eaa788095e          https://9b48ee5/  8257.0
# 2  5a74e9ac53ffb21a20cce117c0ad77ba  https://9634fd0/1409e548  3150.0
# 3  af735816ca19115431ae3d89518c8c91          https://9b48ee5/  2740.0
# 4  364f0ae0a3f29a685c4fb5bae6033b9a          https://9b48ee5/  4863.0
#
#           browser browser_version       os os_version country_id region_id  \
# 0   Chrome Mobile         119.0.0  Android         10     c31b4e    470e75
# 1   Chrome Mobile         111.0.0  Android         10     c31b4e    44520b
# 2  Yandex Browser         20.12.5  Android         11     c31b4e    616bb9
# 3   Chrome Mobile         119.0.0  Android         10     c31b4e    3c9dca
# 4  Yandex Browser         18.11.1  Android      4.4.4     c31b4e    776e76
#
#   timezone_id  ...  component0  component1  component2  component3  \
# 0      f6155e  ...       11731        4045       22213       -1184
# 1      e56e80  ...       11731        4045       22213       -1184
# 2      af47f1  ...       12498        2451       10304       -6380
# 3      e56e80  ...       11731        4045       22213       -1184
# 4     10b7947  ...       11731        4045       22213       -1184
#
#    component4  component5  component6  component7  component8  component9
# 0       -8992        9381       -3496       -3120        -899       16817
# 1       -8992        9381       -3496       -3120        -899       16817
# 2       11608        3106       -2188       10573        3347       21870
# 3       -8992        9381       -3496       -3120        -899       16817
# 4       -8992        9381       -3496       -3120        -899       16817
#
# [5 rows x 21 columns]

# %%
for i in  full_train.columns:
    print(i, full_train[i].nunique())
# Out:
# user_id 499999
# referer 135012
# geo_id 2828
# browser 59
# browser_version 1437
# os 13
# os_version 230
# country_id 151
# region_id 259
# timezone_id 218
# target 2
# component0 27196
# component1 31467
# component2 26412
# component3 30622
# component4 30426
# component5 26702
# component6 27506
# component7 28597
# component8 28248
# component9 36867

# %%
#Удалим те колонки, которые не получиться преобразовать в dummy переменные

# %%
full_train = full_train.drop(['referer', 'geo_id'], axis = 1)

# %%
full_train = full_train.drop(['user_id'], axis = 1)

# %%
full_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601289 entries, 0 to 601288
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   browser          601289 non-null  object
#  1   browser_version  601289 non-null  object
#  2   os               601289 non-null  object
#  3   os_version       601289 non-null  object
#  4   country_id       601289 non-null  object
#  5   region_id        601289 non-null  object
#  6   timezone_id      601289 non-null  object
#  7   target           601289 non-null  int64
#  8   component0       601289 non-null  int64
#  9   component1       601289 non-null  int64
#  10  component2       601289 non-null  int64
#  11  component3       601289 non-null  int64
#  12  component4       601289 non-null  int64
#  13  component5       601289 non-null  int64
#  14  component6       601289 non-null  int64
#  15  component7       601289 non-null  int64
#  16  component8       601289 non-null  int64
#  17  component9       601289 non-null  int64
# dtypes: int64(11), object(7)
# memory usage: 82.6+ MB

# %%
full_train.head()
# Out:
#           browser browser_version       os os_version country_id region_id  \
# 0   Chrome Mobile         119.0.0  Android         10     c31b4e    470e75
# 1   Chrome Mobile         111.0.0  Android         10     c31b4e    44520b
# 2  Yandex Browser         20.12.5  Android         11     c31b4e    616bb9
# 3   Chrome Mobile         119.0.0  Android         10     c31b4e    3c9dca
# 4  Yandex Browser         18.11.1  Android      4.4.4     c31b4e    776e76
#
#   timezone_id  target  component0  component1  component2  component3  \
# 0      f6155e       0       11731        4045       22213       -1184
# 1      e56e80       0       11731        4045       22213       -1184
# 2      af47f1       0       12498        2451       10304       -6380
# 3      e56e80       0       11731        4045       22213       -1184
# 4     10b7947       0       11731        4045       22213       -1184
#
#    component4  component5  component6  component7  component8  component9
# 0       -8992        9381       -3496       -3120        -899       16817
# 1       -8992        9381       -3496       -3120        -899       16817
# 2       11608        3106       -2188       10573        3347       21870
# 3       -8992        9381       -3496       -3120        -899       16817
# 4       -8992        9381       -3496       -3120        -899       16817

# %%
#Попробуем также удалить колонки browser_version, os_version в связи с неспособностью нормально их представить в связи с большим количеством различных значений

# %%
full_train = full_train.drop(['browser_version', 'os_version'], axis = 1)

# %%
full_train.head()
# Out:
#           browser       os country_id region_id timezone_id  target  \
# 0   Chrome Mobile  Android     c31b4e    470e75      f6155e       0
# 1   Chrome Mobile  Android     c31b4e    44520b      e56e80       0
# 2  Yandex Browser  Android     c31b4e    616bb9      af47f1       0
# 3   Chrome Mobile  Android     c31b4e    3c9dca      e56e80       0
# 4  Yandex Browser  Android     c31b4e    776e76     10b7947       0
#
#    component0  component1  component2  component3  component4  component5  \
# 0       11731        4045       22213       -1184       -8992        9381
# 1       11731        4045       22213       -1184       -8992        9381
# 2       12498        2451       10304       -6380       11608        3106
# 3       11731        4045       22213       -1184       -8992        9381
# 4       11731        4045       22213       -1184       -8992        9381
#
#    component6  component7  component8  component9
# 0       -3496       -3120        -899       16817
# 1       -3496       -3120        -899       16817
# 2       -2188       10573        3347       21870
# 3       -3496       -3120        -899       16817
# 4       -3496       -3120        -899       16817

# %%
full_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601289 entries, 0 to 601288
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   browser      601289 non-null  object
#  1   os           601289 non-null  object
#  2   country_id   601289 non-null  object
#  3   region_id    601289 non-null  object
#  4   timezone_id  601289 non-null  object
#  5   target       601289 non-null  int64
#  6   component0   601289 non-null  int64
#  7   component1   601289 non-null  int64
#  8   component2   601289 non-null  int64
#  9   component3   601289 non-null  int64
#  10  component4   601289 non-null  int64
#  11  component5   601289 non-null  int64
#  12  component6   601289 non-null  int64
#  13  component7   601289 non-null  int64
#  14  component8   601289 non-null  int64
#  15  component9   601289 non-null  int64
# dtypes: int64(11), object(5)
# memory usage: 73.4+ MB

# %%
full_train['target'] = full_train['target'].astype('category')

# %%
#Также попробуем создать новые датафреймы с различными данными

# %%
from sklearn.metrics import accuracy_score

# %%
full_train_country = full_train.drop(['region_id', 'timezone_id'], axis = 1)
full_train_region = full_train.drop(['country_id', 'timezone_id'], axis = 1)
full_train_timezone = full_train.drop(['region_id', 'country_id'], axis = 1)

# %%
def get_result(models, dict1):
    counter = 0
    for df in models:
        X = df.drop(['target'], axis = 1)
        y = df['target']
        X_dummies = pd.get_dummies(X, drop_first = True)
        X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size = 0.25, random_state = 42)
        scaler = StandardScaler()
        scaler.fit(X_train)
        scaled_X_train = scaler.transform(X_train)
        scaled_X_test = scaler.transform(X_test)
        model = CatBoostClassifier(
            verbose = 0,
            random_state = 42
        )
        param_grid = {'learning_rate': [0.01, 0.05, 0.1],
                    'iterations':[100, 200],
                    'eval_metric': ['Accuracy'],
                    'l2_leaf_reg':[1, 3, 5],
                    'depth': [6, 8, 10]
                    }
        grid = RandomizedSearchCV(estimator = model,
                                param_distributions = param_grid,
                                scoring = 'accuracy',
                                n_iter = 10,
                                cv = 2,
                                verbose = 2,
                                n_jobs = -1)
        grid.fit(scaled_X_train, y_train)
        best = grid.best_estimator_
        y_preds = best.predict(scaled_X_test)
        counter += 1
        dict1[counter] = accuracy_score(y_test, y_preds)
        print(counter)
        print(grid.best_params_)
        print(classification_report(y_test, y_preds))
        print()
        print()
        print()

# %%
dict1 = dict()
dfs = [full_train_country, full_train_region, full_train_timezone, full_train]
get_result(dfs, dict1)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# 1
# {'learning_rate': 0.1, 'l2_leaf_reg': 5, 'iterations': 200, 'eval_metric': 'Accuracy', 'depth': 10}
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79     78305
#            1       0.77      0.77      0.77     72018
#
#     accuracy                           0.78    150323
#    macro avg       0.78      0.78      0.78    150323
# weighted avg       0.78      0.78      0.78    150323
#
#
#
#
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# 2
# {'learning_rate': 0.1, 'l2_leaf_reg': 1, 'iterations': 200, 'eval_metric': 'Accuracy', 'depth': 8}
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78     78305
#            1       0.76      0.76      0.76     72018
#
#     accuracy                           0.77    150323
#    macro avg       0.77      0.77      0.77    150323
# weighted avg       0.77      0.77      0.77    150323
#
#
#
#
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# 3
# {'learning_rate': 0.1, 'l2_leaf_reg': 3, 'iterations': 200, 'eval_metric': 'Accuracy', 'depth': 8}
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78     78305
#            1       0.76      0.75      0.76     72018
#
#     accuracy                           0.77    150323
#    macro avg       0.77      0.77      0.77    150323
# weighted avg       0.77      0.77      0.77    150323
#
#
#
#
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# 4
# {'learning_rate': 0.05, 'l2_leaf_reg': 3, 'iterations': 100, 'eval_metric': 'Accuracy', 'depth': 8}
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77     78305
#            1       0.75      0.73      0.74     72018
#
#     accuracy                           0.76    150323
#    macro avg       0.75      0.75      0.75    150323
# weighted avg       0.76      0.76      0.76    150323

# %%
dict1
# Out:
# {1: 0.7768139273431212,
#  2: 0.7714987061194893,
#  3: 0.769303433273684,
#  4: 0.7551805112990028}

# %%
#Мы видим, что модель лучше всего отработала на данны с country_id, поэтому будем использовать ее
#Попробуем также использовать random_forest

# %%
from sklearn.ensemble import RandomForestClassifier as RF

# %%
def get_result_rf(df):
    X = df.drop(['target'], axis = 1)
    y = df['target']
    X_dummies = pd.get_dummies(X, drop_first = True)
    X_work, _, y_work, _ = train_test_split(X_dummies, y, test_size = 0.9, random_state = 42) #Для использования RandomSearchCV на подвыборке
    X_train, X_test, y_train, y_test = train_test_split(X_work, y_work, test_size = 0.25, random_state = 42)
    scaler = StandardScaler()
    scaler.fit(X_train)
    scaled_X_train = scaler.transform(X_train)
    scaled_X_test = scaler.transform(X_test)
    model = RF()
    param_grid = {'n_estimators':[50, 100],
                  'max_features':['sqrt', 'log2', X_train.shape[1]],
                  'max_depth':[4, 8, 10],
                }
    grid = RandomizedSearchCV(estimator = model,
                                param_distributions = param_grid,
                                scoring = 'accuracy',
                                n_iter = 10,
                                cv = 2,
                                verbose = 2,
                                n_jobs = -1)
    grid.fit(scaled_X_train, y_train)
    best = grid.best_estimator_
    y_preds = best.predict(scaled_X_test)
    print(grid.best_params_)
    print(classification_report(y_test, y_preds))

# %%
get_result_rf(full_train_country)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# {'n_estimators': 50, 'max_features': 230, 'max_depth': 10}
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77      7844
#            1       0.76      0.74      0.75      7188
#
#     accuracy                           0.76     15032
#    macro avg       0.76      0.76      0.76     15032
# weighted avg       0.76      0.76      0.76     15032

# %%
#random forest показал хуже результаты, поэтому попробуем улучшить предыдущую модель

# %%
def get_result_gridsearch(df):
    X = df.drop(['target'], axis = 1)
    y = df['target']
    X_dummies = pd.get_dummies(X, drop_first = True)
    X_work, _, y_work, _ = train_test_split(X_dummies, y, test_size = 0.9, random_state = 42) #Для использования RandomSearchCV на подвыборке
    X_train, X_test, y_train, y_test = train_test_split(X_work, y_work, test_size = 0.25, random_state = 42)
    scaler = StandardScaler()
    scaler.fit(X_train)
    scaled_X_train = scaler.transform(X_train)
    scaled_X_test = scaler.transform(X_test)
    model = CatBoostClassifier(
        verbose=0,
        random_state = 42
    )
    param_grid = {'learning_rate': [0.1, 0.15],
                    'iterations':[200, 300],
                    'eval_metric': ['Accuracy'],
                    'l2_leaf_reg':[1, 3, 5],
                    'depth': [ 10, 15]
                    }
    grid = GridSearchCV(estimator = model,
                                param_grid = param_grid,
                                scoring = 'accuracy',
                                cv = 2,
                                verbose = 2,
                                n_jobs = -1)
    grid.fit(scaled_X_train, y_train)
    best = grid.best_estimator_
    y_preds = best.predict(scaled_X_test)
    print(grid.best_params_)
    print(classification_report(y_test, y_preds))

# %%
get_result_gridsearch(full_train_country)
# Out:
# Fitting 2 folds for each of 54 candidates, totalling 108 fits
# {'depth': 10, 'eval_metric': 'Accuracy', 'iterations': 200, 'l2_leaf_reg': 3, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      7844
#            1       0.77      0.75      0.76      7188
#
#     accuracy                           0.78     15032
#    macro avg       0.78      0.77      0.77     15032
# weighted avg       0.78      0.78      0.78     15032

# %%
#{'depth': 10, 'eval_metric': 'Accuracy', 'iterations': 200, 'l2_leaf_reg': 3, 'learning_rate': 0.1}

# %%
X = full_train_country.drop(['target'], axis = 1)
y = full_train_country['target']
X_dummies = pd.get_dummies(X, drop_first = True)
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size = 0.25, random_state = 42)
scaler = StandardScaler()
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)
model = CatBoostClassifier(depth = 10, eval_metric = 'Accuracy', iterations = 200, l2_leaf_reg = 3, learning_rate=0.1)
model.fit(scaled_X_train, y_train)
# Out:
# 0:	learn: 0.7336052	total: 53.6ms	remaining: 10.7s
# 1:	learn: 0.7364857	total: 106ms	remaining: 10.5s
# 2:	learn: 0.7386987	total: 155ms	remaining: 10.2s
# 3:	learn: 0.7400846	total: 204ms	remaining: 9.99s
# 4:	learn: 0.7403130	total: 251ms	remaining: 9.79s
# 5:	learn: 0.7428964	total: 302ms	remaining: 9.75s
# 6:	learn: 0.7426569	total: 350ms	remaining: 9.66s
# 7:	learn: 0.7434019	total: 401ms	remaining: 9.62s
# 8:	learn: 0.7424795	total: 450ms	remaining: 9.55s
# 9:	learn: 0.7435328	total: 498ms	remaining: 9.47s
# 10:	learn: 0.7439652	total: 547ms	remaining: 9.4s
# 2  1700969752  6ef1eedbdb72554e53e69782066065c5  https://72879b4/12411b9e
# 3  1700991608  7e057293ecae62985a327b7af51858ea          https://9b48ee5/
# 4  1701019815  a27bd7ce8828497823fa8d5d05e7bbf7          https://9b48ee5/
#
#    geo_id        browser browser_version       os os_version
# 0    8816  Chrome Mobile       96.0.4664  Android         12
# 1    3663         Chrome      116.0.5845  Android         10
# 2    2336         Chrome         114.0.0  Android         10
# 3    9652  Chrome Mobile       91.0.4472  Android         11
# 4    3871  Chrome Mobile         119.0.0  Android         10

# %%
test_with_geo = pd.merge(test, geo_info, on = 'geo_id', how = 'inner')

# %%
test_with_geo.head()
# Out:
#    request_ts                           user_id                   referer  \
# 0  1700993094  c2802dadd33d8ae09bb366bdd41212ea          https://9b48ee5/
# 1  1701005579  e5b1988db74527ec092f28b0bbfdaac9          https://9b48ee5/
# 2  1700969752  6ef1eedbdb72554e53e69782066065c5  https://72879b4/12411b9e
# 3  1700991608  7e057293ecae62985a327b7af51858ea          https://9b48ee5/
# 4  1701019815  a27bd7ce8828497823fa8d5d05e7bbf7          https://9b48ee5/
#
#    geo_id        browser browser_version       os os_version country_id  \
# 0    8816  Chrome Mobile       96.0.4664  Android         12     c31b4e
# 1    3663         Chrome      116.0.5845  Android         10     c31b4e
# 2    2336         Chrome         114.0.0  Android         10     c31b4e
# 3    9652  Chrome Mobile       91.0.4472  Android         11     c31b4e
# 4    3871  Chrome Mobile         119.0.0  Android         10     c31b4e
#
#   region_id timezone_id
# 0    36e3f3      f6155e
# 1    8ccc01      e56e80
# 2    1fbfa5      e56e80
# 3     f66ff      f6155e
# 4    245864      e56e80

# %%
full_test = pd.merge(test_with_geo, referer_vectors, on = 'referer', how = "inner")

# %%
full_test.isnull().sum()
# Out:
# request_ts         0
# user_id            0
# referer            0
# geo_id             0
# browser            0
# browser_version    0
# os                 0
# os_version         0
# country_id         0
# region_id          0
# timezone_id        0
# component0         0
# component1         0
# component2         0
# component3         0
# component4         0
# component5         0
# component6         0
# component7         0
# component8         0
# component9         0
# dtype: int64

# %%
full_test.head()
# Out:
#    request_ts                           user_id                   referer  \
# 0  1700993094  c2802dadd33d8ae09bb366bdd41212ea          https://9b48ee5/
# 1  1701005579  e5b1988db74527ec092f28b0bbfdaac9          https://9b48ee5/
# 2  1700969752  6ef1eedbdb72554e53e69782066065c5  https://72879b4/12411b9e
# 3  1700991608  7e057293ecae62985a327b7af51858ea          https://9b48ee5/
# 4  1701019815  a27bd7ce8828497823fa8d5d05e7bbf7          https://9b48ee5/
#
#    geo_id        browser browser_version       os os_version country_id  \
# 0    8816  Chrome Mobile       96.0.4664  Android         12     c31b4e
# 1    3663         Chrome      116.0.5845  Android         10     c31b4e
# 2    2336         Chrome         114.0.0  Android         10     c31b4e
# 3    9652  Chrome Mobile       91.0.4472  Android         11     c31b4e
# 4    3871  Chrome Mobile         119.0.0  Android         10     c31b4e
#
#   region_id  ... component0  component1  component2  component3  component4  \
# 0    36e3f3  ...      11731        4045       22213       -1184       -8992
# 1    8ccc01  ...      11731        4045       22213       -1184       -8992
# 2    1fbfa5  ...      -7307       11682        9741       13564       13577
# 3     f66ff  ...      11731        4045       22213       -1184       -8992
# 4    245864  ...      11731        4045       22213       -1184       -8992
#
#    component5  component6  component7  component8  component9
# 0        9381       -3496       -3120        -899       16817
# 1        9381       -3496       -3120        -899       16817
# 2        1200       10169       16461       -3932        3340
# 3        9381       -3496       -3120        -899       16817
# 4        9381       -3496       -3120        -899       16817
#
# [5 rows x 21 columns]

# %%
#Удалим ненужные колонки

# %%
users = full_test['user_id']

# %%
full_test = full_test.drop(['user_id', 'request_ts', 'referer', 'browser_version', 'os_version', 'region_id', 'timezone_id'], axis = 1)

# %%
full_test = full_test.drop(['geo_id'], axis = 1)

# %%
full_test.head()
# Out:
#          browser       os country_id  component0  component1  component2  \
# 0  Chrome Mobile  Android     c31b4e       11731        4045       22213
# 1         Chrome  Android     c31b4e       11731        4045       22213
# 2         Chrome  Android     c31b4e       -7307       11682        9741
# 3  Chrome Mobile  Android     c31b4e       11731        4045       22213
# 4  Chrome Mobile  Android     c31b4e       11731        4045       22213
#
#    component3  component4  component5  component6  component7  component8  \
# 0       -1184       -8992        9381       -3496       -3120        -899
# 1       -1184       -8992        9381       -3496       -3120        -899
# 2       13564       13577        1200       10169       16461       -3932
# 3       -1184       -8992        9381       -3496       -3120        -899
# 4       -1184       -8992        9381       -3496       -3120        -899
#
#    component9
# 0       16817
# 1       16817
# 2        3340
# 3       16817
# 4       16817

# %%
X = pd.get_dummies(full_test, drop_first = True)

# %%
scaled_X_full_test = scaler.fit_transform(X)

# %%
y_preds = model.predict(scaled_X_test)

# %%
finished_df = pd.concat([users, pd.DataFrame(y_preds)], axis = 1)

# %%
finished_df.head()
# Out:
#                             user_id    0
# 0  c2802dadd33d8ae09bb366bdd41212ea  1.0
# 1  e5b1988db74527ec092f28b0bbfdaac9  0.0
# 2  6ef1eedbdb72554e53e69782066065c5  0.0
# 3  7e057293ecae62985a327b7af51858ea  1.0
# 4  a27bd7ce8828497823fa8d5d05e7bbf7  1.0

# %%
finished_df_unique = finished_df[['user_id', 0]].drop_duplicates(subset = ['user_id'])

# %%
answer = test_users.merge(finished_df_unique, on = 'user_id', how = "left")

# %%
answer.isnull().sum()
# Out:
# user_id    0
# 0          0
# dtype: int64

# %%
test_users.shape
# Out:
# (85000, 1)

# %%
answer.head()
# Out:
#                             user_id  0
# 0  c2802dadd33d8ae09bb366bdd41212ea  1
# 1  e5b1988db74527ec092f28b0bbfdaac9  0
# 2  6ef1eedbdb72554e53e69782066065c5  0
# 3  7e057293ecae62985a327b7af51858ea  1
# 4  a27bd7ce8828497823fa8d5d05e7bbf7  1

# %%
answer[0] = answer[0].astype(int)

# %%
answer.rename(columns = {0:'target'}, inplace = True)

# %%
answer.head()
# Out:
#                             user_id  target
# 0  c2802dadd33d8ae09bb366bdd41212ea       1
# 1  e5b1988db74527ec092f28b0bbfdaac9       0
# 2  6ef1eedbdb72554e53e69782066065c5       0
# 3  7e057293ecae62985a327b7af51858ea       1
# 4  a27bd7ce8828497823fa8d5d05e7bbf7       1

# %%
answer.to_csv('test_users_with_target.csv', index = False)
